# %%
import xmltodict
import math
import urllib.request
import itertools
import pandas as pd
import pickle   
from sklearn.utils import shuffle
import time
import numpy as np
import traceback

# %%
import sqlite3
from sqlite3 import Error

def create_con(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

def create_table(conn, create_table_sql):
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
        conn.commit()
    except Error as e:
        print(e)

def create_game(conn, game):
    sql = """ INSERT INTO games(name)
              VALUES(?) """
    c = conn.cursor()
    c.execute(sql, game)
    conn.commit()
    return c.lastrowid


def create_reviews(conn, reviews):
    sql = """ INSERT INTO reviews(user, rating, comment, ID)
              VALUES(?,?,?,?) """
    cur = conn.cursor()
    for review in reviews:
        cur.execute(sql,review)
    cur.execute(sql, review)
    conn.commit()
    return cur.lastrowid

def do_sql(conn,sql):
    cur = conn.cursor()
    cur.execute(sql)
    rows = cur.fetchall()
    for row in rows:
        print(row)

def count_reviews(conn):
    cur = conn.cursor()
    print(cur.execute("SELECT COUNT (*) FROM reviews;").fetchall()[0])

def count_distinct_reviews(conn):
    cur = conn.cursor()
    print(cur.execute("SELECT COUNT(*) FROM (SELECT DISTINCT * FROM reviews);").fetchall()[0])

def del_all_records(conn):
    cur = conn.cursor()
    cur.execute("DROP TABLE IF EXISTS reviews")
    cur.execute("DROP TABLE IF EXISTS games")
    conn.commit()

# %%
from urllib.request import urlopen
# the original csv from https://raw.githubusercontent.com/beefsack/bgg-ranking-historicals/master/2017-02-21.csv
# The ID's where used in API calls to retrieve the game reviews
link="https://raw.githubusercontent.com/beefsack/bgg-ranking-historicals/master/2020-08-19.csv"
f = urlopen(link)
games = pd.read_csv(f)
games.describe()
games.sort_values('Users rated',ascending=False,inplace=True)
games[:5]
# Out:
#         ID         Name  Year  Rank  Average  Bayes average  Users rated  \
# 90   30549     Pandemic  2008    91     7.62          7.518        96186
# 172    822  Carcassonne  2000   173     7.42          7.311        96181
# 380     13        Catan  1995   381     7.16          7.001        96171
# 49   68448    7 Wonders  2010    50     7.76          7.662        79830
# 87   36218     Dominion  2008    88     7.63          7.521        74933
#
#                             URL  \
# 90    /boardgame/30549/pandemic
# 172  /boardgame/822/carcassonne
# 380         /boardgame/13/catan
# 49   /boardgame/68448/7-wonders
# 87    /boardgame/36218/dominion
#
#                                              Thumbnail
# 90   https://cf.geekdo-images.com/micro/img/0m3-oqB...
# 172  https://cf.geekdo-images.com/micro/img/z0tTaij...
# 380  https://cf.geekdo-images.com/micro/img/e0y6Bog...
# 49   https://cf.geekdo-images.com/micro/img/h-Ejv31...
# 87   https://cf.geekdo-images.com/micro/img/VYp2s2f...

# %%
from sqlalchemy import create_engine

sql_create_table_reviews = """ CREATE TABLE IF NOT EXISTS reviews(
                                    review_id integer PRIMARY KEY,
                                    user text NOT NULL,
                                    rating NOT NULL,
                                    comment text,              
                                    ID integer,
                                    FOREIGN KEY(ID) REFERENCES games(ID));"""

conn = create_con('test.db')
del_all_records(conn) # empty database (optional)

if conn:
    engine = create_engine('sqlite:///%s' % 'test.db', echo=True)
    games[['ID','Name']].to_sql('games', con=engine)
    # c = conn.cursor()
    # c.execute(""" DROP TABLE IF EXISTS games""")
    # create_table(conn, sql_create_table_games)
    # c.execute(""" DROP TABLE IF EXISTS reviews""")
    create_table(conn, sql_create_table_reviews)
    count_reviews(conn)
# Out:
# 2020-08-19 21:00:05,058 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-08-19 21:00:05,066 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-19 21:00:05,073 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-08-19 21:00:05,080 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-19 21:00:05,090 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("games")
# 2020-08-19 21:00:05,100 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-19 21:00:05,108 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("games")
# 2020-08-19 21:00:05,119 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-19 21:00:05,137 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE games (
# 	"index" BIGINT,
# 	"ID" BIGINT,
# 	"Name" TEXT
# )
#
#
# 2020-08-19 21:00:05,142 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-19 21:00:05,170 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-19 21:00:05,173 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_games_index ON games ("index")
# 2020-08-19 21:00:05,176 INFO sqlalchemy.engine.base.Engine ()
# 2020-08-19 21:00:05,206 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-19 21:00:05,223 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-08-19 21:00:05,556 INFO sqlalchemy.engine.base.Engine INSERT INTO games ("index", "ID", "Name") VALUES (?, ?, ?)
# 2020-08-19 21:00:05,564 INFO sqlalchemy.engine.base.Engine ((90, 30549, 'Pandemic'), (172, 822, 'Carcassonne'), (380, 13, 'Catan'), (49, 68448, '7 Wonders'), (87, 36218, 'Dominion'), (164, 9209, 'Ticket to Ride'), (80, 178900, 'Codenames'), (28, 31260, 'Agricola')  ... displaying 10 of 19330 total bound parameter sets ...  (13932, 284862, 'Beasty Borders'), (12882, 281515, 'Company of Heroes'))
# 2020-08-19 21:00:06,033 INFO sqlalchemy.engine.base.Engine COMMIT
# (0,)

# %%
def gen_batches():
    num_batches = len(games)//100
    for b in range(num_batches):
        result = slice(b*100,(b+1)*100)
        if b*100>-1:
            yield result
    yield slice((b+1)*100,len(games)+1)

# %%
def number_rating_pages(game_id):
    url = 'https://www.boardgamegeek.com/xmlapi2/thing?id='+str(game_id)+'&ratingcomments=1'
    u = urllib.request.urlopen(url).read()#The url you want to open
    doc = xmltodict.parse(u)
    return math.ceil(int(doc['items']['item']['comments']['@totalitems'])/100)

# %%
def get_url_result(ids,p): # given a url of an object and a page, return list of dicts with the comments
    url = 'https://www.boardgamegeek.com/xmlapi2/thing?id='+ids+'&ratingcomments=1'
    url += '&&page='+str(p)
    u = urllib.request.urlopen(url).read()#The url you want to open
    doc = xmltodict.parse(u)
    return doc

# %%
def process_result(url_result):
    remove_list = []
    for g in url_result['items']['item']:
        if not isinstance(g, str):
            if 'comment' in g['comments'].keys():
                try:
                    review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
                    create_reviews(conn,review_tup)
                except Exception as e:
                    print(e,traceback.format_exc())
            else:
                remove_list.append(int(g['@id']))
        else:
            print('crazy str',g)
    return remove_list

# %%
conn = create_con('test.db')
game_generator = gen_batches()

# get all games, but do this per batch of 100 games
for batch in game_generator: 
    print('new batch,', batch)
    # list of games
    games_in_batch = list(games['ID'][batch])
    
    #get maximum number of pages from game on top of the batch
    num_pages = number_rating_pages(games_in_batch[0])+1
    if num_pages>0:
        # get all the pages, quering as little games as possible and store the results
        for p in range(0,num_pages):
            for tryout in range(5):
                try:
                    print('next query for page {} for {} games'.format(p,len(games_in_batch)))
                    #print('games still in batch are \n',games_in_batch)
                    if not games_in_batch:
                        print('gamelist empty!')
                        break
                    # convert list of current games to url input
                    ids = ','.join(str(g) for g in games_in_batch)
                    #query API and parse to dictionary
                    url_result = get_url_result(ids,p)
                    print('data retrieved')
                    # remove games that have no comment, they dont have to be queried again
                    removelist = process_result(url_result)
                    #print('to remove',removelist)
                    games_in_batch = [g for g in games_in_batch if g not in removelist]
                    time.sleep(8)
                    # if p%1000==0:
                    #     with open('ratings.pickle', 'wb') as handle:
                    #         pickle.dump(rating_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
                    break
                except Exception as e:
                    print('error',tryout,p,e)
                    time.sleep(30)
print('all done')
conn.close()
# Out:
# new batch, slice(0, 100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# next query for page 2 for 100 games
# data retrieved
# next query for page 3 for 100 games
# data retrieved
# next query for page 4 for 100 games
# data retrieved
# next query for page 5 for 100 games
# data retrieved
# next query for page 6 for 100 games
# data retrieved
# next query for page 7 for 100 games
# data retrieved
# next query for page 8 for 100 games
# data retrieved
# next query for page 9 for 100 games
# data retrieved
# next query for page 10 for 100 games
# data retrieved
# next query for page 11 for 100 games
# data retrieved
# next query for page 12 for 100 games
# data retrieved
# next query for page 13 for 100 games
# data retrieved
# next query for page 14 for 100 games
# data retrieved
# next query for page 15 for 100 games
# data retrieved
# next query for page 16 for 100 games
# data retrieved
# next query for page 17 for 100 games
# data retrieved
# next query for page 18 for 100 games
# data retrieved
# next query for page 19 for 100 games
# data retrieved
# next query for page 20 for 100 games
# data retrieved
# next query for page 21 for 100 games
# data retrieved
# next query for page 22 for 100 games
# data retrieved
# next query for page 23 for 100 games
# data retrieved
# next query for page 24 for 100 games
# data retrieved
# next query for page 25 for 100 games
# data retrieved
# next query for page 26 for 100 games
# data retrieved
# next query for page 27 for 100 games
# data retrieved
# next query for page 28 for 100 games
# data retrieved
# next query for page 29 for 100 games
# data retrieved
# next query for page 30 for 100 games
# data retrieved
# next query for page 31 for 100 games
# data retrieved
# next query for page 32 for 100 games
# data retrieved
# next query for page 33 for 100 games
# error 0 33 HTTP Error 502: Bad Gateway
# next query for page 33 for 100 games
# data retrieved
# next query for page 34 for 100 games
# data retrieved
# next query for page 35 for 100 games
# data retrieved
# next query for page 36 for 100 games
# data retrieved
# next query for page 37 for 100 games
# data retrieved
# next query for page 38 for 100 games
# data retrieved
# next query for page 39 for 100 games
# data retrieved
# next query for page 40 for 100 games
# data retrieved
# next query for page 41 for 100 games
# data retrieved
# next query for page 42 for 100 games
# data retrieved
# next query for page 43 for 100 games
# data retrieved
# next query for page 44 for 100 games
# data retrieved
# next query for page 45 for 100 games
# data retrieved
# next query for page 46 for 100 games
# data retrieved
# next query for page 47 for 100 games
# data retrieved
# next query for page 48 for 100 games
# data retrieved
# next query for page 49 for 100 games
# data retrieved
# next query for page 50 for 100 games
# data retrieved
# next query for page 51 for 100 games
# data retrieved
# next query for page 52 for 100 games
# data retrieved
# next query for page 53 for 100 games
# data retrieved
# next query for page 54 for 100 games
# data retrieved
# next query for page 55 for 100 games
# data retrieved
# next query for page 56 for 100 games
# data retrieved
# next query for page 57 for 100 games
# data retrieved
# next query for page 58 for 100 games
# data retrieved
# next query for page 59 for 100 games
# data retrieved
# next query for page 60 for 100 games
# data retrieved
# next query for page 61 for 100 games
# error 0 61 HTTP Error 502: Bad Gateway
# next query for page 61 for 100 games
# data retrieved
# next query for page 62 for 100 games
# data retrieved
# next query for page 63 for 100 games
# data retrieved
# next query for page 64 for 100 games
# data retrieved
# next query for page 65 for 100 games
# data retrieved
# next query for page 66 for 100 games
# data retrieved
# next query for page 67 for 100 games
# data retrieved
# next query for page 68 for 100 games
# data retrieved
# next query for page 69 for 100 games
# data retrieved
# next query for page 70 for 100 games
# data retrieved
# next query for page 71 for 100 games
# data retrieved
# next query for page 72 for 100 games
# data retrieved
# next query for page 73 for 100 games
# data retrieved
# next query for page 74 for 100 games
# data retrieved
# next query for page 75 for 100 games
# data retrieved
# next query for page 76 for 100 games
# data retrieved
# next query for page 77 for 100 games
# data retrieved
# next query for page 78 for 100 games
# data retrieved
# next query for page 79 for 100 games
# data retrieved
# next query for page 80 for 100 games
# data retrieved
# next query for page 81 for 100 games
# data retrieved
# next query for page 82 for 100 games
# data retrieved
# next query for page 83 for 100 games
# data retrieved
# next query for page 84 for 100 games
# data retrieved
# next query for page 85 for 100 games
# data retrieved
# next query for page 86 for 100 games
# data retrieved
# next query for page 87 for 100 games
# data retrieved
# next query for page 88 for 100 games
# data retrieved
# next query for page 89 for 100 games
# data retrieved
# next query for page 90 for 100 games
# data retrieved
# next query for page 91 for 100 games
# data retrieved
# next query for page 92 for 100 games
# data retrieved
# next query for page 93 for 100 games
# data retrieved
# next query for page 94 for 100 games
# data retrieved
# next query for page 95 for 100 games
# data retrieved
# next query for page 96 for 100 games
# data retrieved
# next query for page 97 for 100 games
# data retrieved
# next query for page 98 for 100 games
# data retrieved
# next query for page 99 for 100 games
# data retrieved
# next query for page 100 for 100 games
# data retrieved
# next query for page 101 for 100 games
# error 0 101 HTTP Error 502: Bad Gateway
# next query for page 101 for 100 games
# data retrieved
# next query for page 102 for 100 games
# data retrieved
# next query for page 103 for 100 games
# data retrieved
# next query for page 104 for 100 games
# data retrieved
# next query for page 105 for 100 games
# data retrieved
# next query for page 106 for 100 games
# data retrieved
# next query for page 107 for 100 games
# data retrieved
# next query for page 108 for 100 games
# data retrieved
# next query for page 109 for 100 games
# data retrieved
# next query for page 110 for 100 games
# data retrieved
# next query for page 111 for 100 games
# data retrieved
# next query for page 112 for 100 games
# data retrieved
# next query for page 113 for 100 games
# data retrieved
# next query for page 114 for 100 games
# data retrieved
# next query for page 115 for 100 games
# data retrieved
# next query for page 116 for 100 games
# data retrieved
# next query for page 117 for 100 games
# data retrieved
# next query for page 118 for 100 games
# data retrieved
# next query for page 119 for 100 games
# data retrieved
# next query for page 120 for 100 games
# data retrieved
# next query for page 121 for 100 games
# data retrieved
# next query for page 122 for 100 games
# data retrieved
# next query for page 123 for 100 games
# data retrieved
# next query for page 124 for 100 games
# data retrieved
# next query for page 125 for 100 games
# data retrieved
# next query for page 126 for 100 games
# data retrieved
# next query for page 127 for 100 games
# data retrieved
# next query for page 128 for 100 games
# data retrieved
# next query for page 129 for 100 games
# data retrieved
# next query for page 130 for 100 games
# data retrieved
# next query for page 131 for 100 games
# data retrieved
# next query for page 132 for 100 games
# data retrieved
# next query for page 133 for 100 games
# data retrieved
# next query for page 134 for 100 games
# data retrieved
# next query for page 135 for 100 games
# data retrieved
# next query for page 136 for 100 games
# data retrieved
# next query for page 137 for 100 games
# data retrieved
# next query for page 138 for 100 games
# data retrieved
# next query for page 139 for 100 games
# data retrieved
# next query for page 140 for 100 games
# data retrieved
# next query for page 141 for 100 games
# data retrieved
# next query for page 142 for 100 games
# data retrieved
# next query for page 143 for 100 games
# data retrieved
# next query for page 144 for 100 games
# data retrieved
# next query for page 145 for 100 games
# data retrieved
# next query for page 146 for 100 games
# data retrieved
# next query for page 147 for 100 games
# data retrieved
# next query for page 148 for 100 games
# data retrieved
# next query for page 149 for 100 games
# data retrieved
# next query for page 150 for 100 games
# data retrieved
# next query for page 151 for 100 games
# data retrieved
# next query for page 152 for 100 games
# data retrieved
# next query for page 153 for 100 games
# data retrieved
# next query for page 154 for 100 games
# data retrieved
# next query for page 155 for 100 games
# data retrieved
# next query for page 156 for 100 games
# data retrieved
# next query for page 157 for 100 games
# data retrieved
# next query for page 158 for 100 games
# data retrieved
# next query for page 159 for 100 games
# data retrieved
# next query for page 160 for 100 games
# data retrieved
# next query for page 161 for 100 games
# data retrieved
# next query for page 162 for 100 games
# data retrieved
# next query for page 163 for 100 games
# data retrieved
# next query for page 164 for 100 games
# data retrieved
# next query for page 165 for 100 games
# data retrieved
# next query for page 166 for 100 games
# data retrieved
# next query for page 167 for 100 games
# data retrieved
# next query for page 168 for 100 games
# data retrieved
# next query for page 169 for 100 games
# data retrieved
# next query for page 170 for 100 games
# data retrieved
# next query for page 171 for 100 games
# data retrieved
# next query for page 172 for 100 games
# data retrieved
# next query for page 173 for 100 games
# data retrieved
# next query for page 174 for 100 games
# data retrieved
# next query for page 175 for 100 games
# data retrieved
# next query for page 176 for 100 games
# data retrieved
# next query for page 177 for 100 games
# data retrieved
# next query for page 178 for 100 games
# data retrieved
# next query for page 179 for 100 games
# data retrieved
# next query for page 180 for 100 games
# data retrieved
# next query for page 181 for 100 games
# data retrieved
# next query for page 182 for 100 games
# data retrieved
# next query for page 183 for 100 games
# data retrieved
# next query for page 184 for 100 games
# data retrieved
# next query for page 185 for 100 games
# data retrieved
# next query for page 186 for 100 games
# data retrieved
# next query for page 187 for 100 games
# data retrieved
# next query for page 188 for 100 games
# data retrieved
# next query for page 189 for 100 games
# data retrieved
# next query for page 190 for 100 games
# data retrieved
# next query for page 191 for 100 games
# data retrieved
# next query for page 192 for 100 games
# data retrieved
# next query for page 193 for 100 games
# data retrieved
# next query for page 194 for 100 games
# data retrieved
# next query for page 195 for 100 games
# data retrieved
# next query for page 196 for 100 games
# data retrieved
# next query for page 197 for 100 games
# data retrieved
# next query for page 198 for 100 games
# data retrieved
# next query for page 199 for 100 games
# data retrieved
# next query for page 200 for 100 games
# data retrieved
# next query for page 201 for 100 games
# data retrieved
# next query for page 202 for 100 games
# data retrieved
# next query for page 203 for 100 games
# data retrieved
# next query for page 204 for 100 games
# data retrieved
# next query for page 205 for 100 games
# data retrieved
# next query for page 206 for 100 games
# data retrieved
# next query for page 207 for 100 games
# data retrieved
# next query for page 208 for 100 games
# data retrieved
# next query for page 209 for 100 games
# data retrieved
# next query for page 210 for 100 games
# data retrieved
# next query for page 211 for 100 games
# data retrieved
# next query for page 212 for 100 games
# data retrieved
# next query for page 213 for 100 games
# data retrieved
# next query for page 214 for 100 games
# data retrieved
# next query for page 215 for 100 games
# data retrieved
# next query for page 216 for 100 games
# data retrieved
# next query for page 217 for 100 games
# data retrieved
# next query for page 218 for 100 games
# data retrieved
# next query for page 219 for 100 games
# data retrieved
# next query for page 220 for 100 games
# data retrieved
# next query for page 221 for 100 games
# data retrieved
# next query for page 222 for 99 games
# data retrieved
# next query for page 223 for 98 games
# data retrieved
# next query for page 224 for 98 games
# data retrieved
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# next query for page 225 for 97 games
# data retrieved
# next query for page 226 for 95 games
# data retrieved
# next query for page 227 for 95 games
# data retrieved
# next query for page 228 for 95 games
# data retrieved
# next query for page 229 for 94 games
# data retrieved
# next query for page 230 for 92 games
# data retrieved
# next query for page 231 for 90 games
# data retrieved
# next query for page 232 for 89 games
# data retrieved
# next query for page 233 for 87 games
# data retrieved
# next query for page 234 for 87 games
# data retrieved
# next query for page 235 for 87 games
# data retrieved
# next query for page 236 for 87 games
# data retrieved
# next query for page 237 for 87 games
# data retrieved
# next query for page 238 for 87 games
# data retrieved
# next query for page 239 for 87 games
# data retrieved
# next query for page 240 for 87 games
# data retrieved
# next query for page 241 for 86 games
# data retrieved
# next query for page 242 for 86 games
# data retrieved
# next query for page 243 for 86 games
# data retrieved
# next query for page 244 for 86 games
# data retrieved
# next query for page 245 for 86 games
# data retrieved
# next query for page 246 for 84 games
# data retrieved
# next query for page 247 for 84 games
# data retrieved
# next query for page 248 for 84 games
# data retrieved
# next query for page 249 for 84 games
# data retrieved
# next query for page 250 for 83 games
# data retrieved
# next query for page 251 for 81 games
# data retrieved
# next query for page 252 for 79 games
# data retrieved
# next query for page 253 for 77 games
# data retrieved
# next query for page 254 for 77 games
# data retrieved
# next query for page 255 for 77 games
# data retrieved
# next query for page 256 for 76 games
# data retrieved
# next query for page 257 for 76 games
# data retrieved
# next query for page 258 for 76 games
# data retrieved
# next query for page 259 for 74 games
# data retrieved
# next query for page 260 for 73 games
# data retrieved
# next query for page 261 for 72 games
# data retrieved
# next query for page 262 for 71 games
# data retrieved
# next query for page 263 for 69 games
# data retrieved
# next query for page 264 for 69 games
# data retrieved
# next query for page 265 for 69 games
# data retrieved
# next query for page 266 for 67 games
# data retrieved
# next query for page 267 for 67 games
# data retrieved
# next query for page 268 for 66 games
# data retrieved
# next query for page 269 for 65 games
# data retrieved
# next query for page 270 for 65 games
# data retrieved
# next query for page 271 for 64 games
# data retrieved
# next query for page 272 for 62 games
# data retrieved
# next query for page 273 for 62 games
# data retrieved
# next query for page 274 for 62 games
# data retrieved
# next query for page 275 for 62 games
# data retrieved
# next query for page 276 for 62 games
# data retrieved
# next query for page 277 for 61 games
# data retrieved
# next query for page 278 for 59 games
# data retrieved
# next query for page 279 for 59 games
# data retrieved
# next query for page 280 for 59 games
# data retrieved
# next query for page 281 for 59 games
# data retrieved
# next query for page 282 for 58 games
# data retrieved
# next query for page 283 for 58 games
# data retrieved
# next query for page 284 for 57 games
# data retrieved
# next query for page 285 for 56 games
# data retrieved
# next query for page 286 for 56 games
# data retrieved
# next query for page 287 for 55 games
# data retrieved
# next query for page 288 for 55 games
# data retrieved
# next query for page 289 for 54 games
# data retrieved
# next query for page 290 for 54 games
# data retrieved
# next query for page 291 for 54 games
# data retrieved
# next query for page 292 for 54 games
# data retrieved
# next query for page 293 for 53 games
# data retrieved
# next query for page 294 for 53 games
# data retrieved
# next query for page 295 for 52 games
# data retrieved
# next query for page 296 for 51 games
# data retrieved
# next query for page 297 for 51 games
# data retrieved
# next query for page 298 for 51 games
# data retrieved
# next query for page 299 for 50 games
# data retrieved
# next query for page 300 for 50 games
# data retrieved
# next query for page 301 for 50 games
# data retrieved
# next query for page 302 for 50 games
# data retrieved
# next query for page 303 for 50 games
# data retrieved
# next query for page 304 for 50 games
# data retrieved
# next query for page 305 for 50 games
# data retrieved
# next query for page 306 for 50 games
# data retrieved
# next query for page 307 for 50 games
# data retrieved
# next query for page 308 for 49 games
# data retrieved
# next query for page 309 for 49 games
# data retrieved
# next query for page 310 for 49 games
# data retrieved
# next query for page 311 for 49 games
# data retrieved
# next query for page 312 for 49 games
# data retrieved
# next query for page 313 for 49 games
# data retrieved
# next query for page 314 for 49 games
# data retrieved
# next query for page 315 for 49 games
# data retrieved
# next query for page 316 for 49 games
# data retrieved
# next query for page 317 for 48 games
# data retrieved
# next query for page 318 for 48 games
# data retrieved
# next query for page 319 for 48 games
# data retrieved
# next query for page 320 for 47 games
# data retrieved
# next query for page 321 for 47 games
# data retrieved
# next query for page 322 for 47 games
# data retrieved
# next query for page 323 for 46 games
# data retrieved
# next query for page 324 for 46 games
# data retrieved
# next query for page 325 for 44 games
# data retrieved
# next query for page 326 for 44 games
# data retrieved
# next query for page 327 for 44 games
# data retrieved
# next query for page 328 for 44 games
# data retrieved
# next query for page 329 for 44 games
# data retrieved
# next query for page 330 for 44 games
# data retrieved
# next query for page 331 for 44 games
# data retrieved
# next query for page 332 for 44 games
# data retrieved
# next query for page 333 for 44 games
# data retrieved
# next query for page 334 for 43 games
# data retrieved
# next query for page 335 for 43 games
# data retrieved
# next query for page 336 for 43 games
# data retrieved
# next query for page 337 for 43 games
# data retrieved
# next query for page 338 for 42 games
# data retrieved
# next query for page 339 for 42 games
# data retrieved
# next query for page 340 for 42 games
# data retrieved
# next query for page 341 for 42 games
# data retrieved
# next query for page 342 for 42 games
# data retrieved
# next query for page 343 for 42 games
# data retrieved
# next query for page 344 for 41 games
# data retrieved
# next query for page 345 for 40 games
# data retrieved
# next query for page 346 for 39 games
# data retrieved
# next query for page 347 for 39 games
# data retrieved
# next query for page 348 for 39 games
# data retrieved
# next query for page 349 for 39 games
# data retrieved
# next query for page 350 for 39 games
# data retrieved
# next query for page 351 for 39 games
# data retrieved
# next query for page 352 for 39 games
# data retrieved
# next query for page 353 for 38 games
# data retrieved
# next query for page 354 for 38 games
# data retrieved
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# next query for page 355 for 38 games
# data retrieved
# next query for page 356 for 37 games
# data retrieved
# next query for page 357 for 37 games
# data retrieved
# next query for page 358 for 37 games
# data retrieved
# next query for page 359 for 37 games
# data retrieved
# next query for page 360 for 36 games
# data retrieved
# next query for page 361 for 36 games
# data retrieved
# next query for page 362 for 36 games
# data retrieved
# next query for page 363 for 36 games
# data retrieved
# next query for page 364 for 36 games
# data retrieved
# next query for page 365 for 35 games
# data retrieved
# next query for page 366 for 35 games
# data retrieved
# next query for page 367 for 35 games
# data retrieved
# next query for page 368 for 35 games
# data retrieved
# next query for page 369 for 35 games
# data retrieved
# next query for page 370 for 35 games
# data retrieved
# next query for page 371 for 35 games
# data retrieved
# next query for page 372 for 35 games
# data retrieved
# next query for page 373 for 35 games
# data retrieved
# next query for page 374 for 34 games
# data retrieved
# next query for page 375 for 33 games
# data retrieved
# next query for page 376 for 33 games
# data retrieved
# next query for page 377 for 32 games
# data retrieved
# next query for page 378 for 31 games
# data retrieved
# next query for page 379 for 31 games
# data retrieved
# next query for page 380 for 31 games
# data retrieved
# next query for page 381 for 30 games
# data retrieved
# next query for page 382 for 30 games
# data retrieved
# next query for page 383 for 30 games
# data retrieved
# next query for page 384 for 30 games
# data retrieved
# next query for page 385 for 30 games
# data retrieved
# next query for page 386 for 30 games
# data retrieved
# next query for page 387 for 30 games
# data retrieved
# next query for page 388 for 30 games
# data retrieved
# next query for page 389 for 30 games
# data retrieved
# next query for page 390 for 29 games
# data retrieved
# next query for page 391 for 29 games
# data retrieved
# next query for page 392 for 29 games
# data retrieved
# next query for page 393 for 29 games
# data retrieved
# next query for page 394 for 29 games
# data retrieved
# next query for page 395 for 29 games
# data retrieved
# next query for page 396 for 28 games
# data retrieved
# next query for page 397 for 28 games
# data retrieved
# next query for page 398 for 28 games
# data retrieved
# next query for page 399 for 28 games
# data retrieved
# next query for page 400 for 28 games
# data retrieved
# next query for page 401 for 28 games
# data retrieved
# next query for page 402 for 28 games
# data retrieved
# next query for page 403 for 27 games
# data retrieved
# next query for page 404 for 26 games
# data retrieved
# next query for page 405 for 26 games
# data retrieved
# next query for page 406 for 26 games
# data retrieved
# next query for page 407 for 26 games
# data retrieved
# next query for page 408 for 26 games
# data retrieved
# next query for page 409 for 26 games
# data retrieved
# next query for page 410 for 26 games
# data retrieved
# next query for page 411 for 26 games
# data retrieved
# next query for page 412 for 26 games
# data retrieved
# next query for page 413 for 26 games
# data retrieved
# next query for page 414 for 26 games
# data retrieved
# next query for page 415 for 26 games
# data retrieved
# next query for page 416 for 26 games
# data retrieved
# next query for page 417 for 26 games
# data retrieved
# next query for page 418 for 26 games
# data retrieved
# next query for page 419 for 26 games
# data retrieved
# next query for page 420 for 26 games
# data retrieved
# next query for page 421 for 26 games
# data retrieved
# next query for page 422 for 26 games
# data retrieved
# next query for page 423 for 26 games
# data retrieved
# next query for page 424 for 26 games
# data retrieved
# next query for page 425 for 26 games
# data retrieved
# next query for page 426 for 26 games
# data retrieved
# next query for page 427 for 26 games
# data retrieved
# next query for page 428 for 26 games
# data retrieved
# next query for page 429 for 25 games
# data retrieved
# next query for page 430 for 25 games
# data retrieved
# next query for page 431 for 25 games
# data retrieved
# next query for page 432 for 25 games
# data retrieved
# next query for page 433 for 25 games
# data retrieved
# next query for page 434 for 25 games
# data retrieved
# next query for page 435 for 25 games
# data retrieved
# next query for page 436 for 24 games
# data retrieved
# next query for page 437 for 24 games
# data retrieved
# next query for page 438 for 24 games
# data retrieved
# next query for page 439 for 24 games
# data retrieved
# next query for page 440 for 24 games
# data retrieved
# next query for page 441 for 23 games
# data retrieved
# next query for page 442 for 22 games
# data retrieved
# next query for page 443 for 22 games
# data retrieved
# next query for page 444 for 22 games
# data retrieved
# next query for page 445 for 22 games
# data retrieved
# next query for page 446 for 22 games
# data retrieved
# next query for page 447 for 22 games
# data retrieved
# next query for page 448 for 22 games
# data retrieved
# next query for page 449 for 22 games
# data retrieved
# next query for page 450 for 22 games
# data retrieved
# next query for page 451 for 22 games
# data retrieved
# next query for page 452 for 21 games
# data retrieved
# next query for page 453 for 21 games
# data retrieved
# next query for page 454 for 21 games
# data retrieved
# next query for page 455 for 21 games
# data retrieved
# next query for page 456 for 21 games
# data retrieved
# next query for page 457 for 21 games
# data retrieved
# next query for page 458 for 21 games
# data retrieved
# next query for page 459 for 21 games
# data retrieved
# next query for page 460 for 21 games
# data retrieved
# next query for page 461 for 21 games
# data retrieved
# next query for page 462 for 21 games
# data retrieved
# next query for page 463 for 21 games
# data retrieved
# next query for page 464 for 21 games
# data retrieved
# next query for page 465 for 21 games
# data retrieved
# next query for page 466 for 21 games
# data retrieved
# next query for page 467 for 21 games
# data retrieved
# next query for page 468 for 21 games
# data retrieved
# next query for page 469 for 21 games
# data retrieved
# next query for page 470 for 20 games
# data retrieved
# next query for page 471 for 20 games
# data retrieved
# next query for page 472 for 20 games
# data retrieved
# next query for page 473 for 20 games
# data retrieved
# next query for page 474 for 20 games
# data retrieved
# next query for page 475 for 19 games
# data retrieved
# next query for page 476 for 19 games
# data retrieved
# next query for page 477 for 19 games
# data retrieved
# next query for page 478 for 19 games
# data retrieved
# next query for page 479 for 19 games
# data retrieved
# next query for page 480 for 19 games
# data retrieved
# next query for page 481 for 19 games
# data retrieved
# next query for page 482 for 19 games
# data retrieved
# next query for page 483 for 18 games
# data retrieved
# next query for page 484 for 18 games
# data retrieved
# next query for page 485 for 18 games
# data retrieved
# next query for page 486 for 18 games
# data retrieved
# next query for page 487 for 18 games
# data retrieved
# next query for page 488 for 18 games
# data retrieved
# next query for page 489 for 18 games
# data retrieved
# next query for page 490 for 18 games
# data retrieved
# next query for page 491 for 18 games
# data retrieved
# next query for page 492 for 18 games
# data retrieved
# next query for page 493 for 18 games
# data retrieved
# next query for page 494 for 18 games
# data retrieved
# next query for page 495 for 18 games
# data retrieved
# next query for page 496 for 18 games
# data retrieved
# next query for page 497 for 18 games
# data retrieved
# next query for page 498 for 18 games
# data retrieved
# next query for page 499 for 18 games
# data retrieved
# next query for page 500 for 18 games
# data retrieved
# next query for page 501 for 18 games
# data retrieved
# next query for page 502 for 18 games
# data retrieved
# next query for page 503 for 18 games
# data retrieved
# next query for page 504 for 18 games
# data retrieved
# next query for page 505 for 18 games
# data retrieved
# next query for page 506 for 18 games
# data retrieved
# next query for page 507 for 18 games
# data retrieved
# next query for page 508 for 18 games
# data retrieved
# next query for page 509 for 18 games
# data retrieved
# next query for page 510 for 18 games
# data retrieved
# next query for page 511 for 18 games
# data retrieved
# next query for page 512 for 18 games
# data retrieved
# next query for page 513 for 18 games
# data retrieved
# next query for page 514 for 18 games
# data retrieved
# next query for page 515 for 18 games
# data retrieved
# next query for page 516 for 18 games
# data retrieved
# next query for page 517 for 18 games
# data retrieved
# next query for page 518 for 18 games
# data retrieved
# next query for page 519 for 18 games
# data retrieved
# next query for page 520 for 18 games
# data retrieved
# next query for page 521 for 18 games
# data retrieved
# next query for page 522 for 18 games
# data retrieved
# next query for page 523 for 18 games
# data retrieved
# next query for page 524 for 18 games
# data retrieved
# next query for page 525 for 18 games
# data retrieved
# next query for page 526 for 18 games
# data retrieved
# next query for page 527 for 18 games
# data retrieved
# next query for page 528 for 18 games
# data retrieved
# next query for page 529 for 18 games
# data retrieved
# next query for page 530 for 18 games
# data retrieved
# next query for page 531 for 18 games
# data retrieved
# next query for page 532 for 17 games
# data retrieved
# next query for page 533 for 17 games
# data retrieved
# next query for page 534 for 17 games
# data retrieved
# next query for page 535 for 17 games
# data retrieved
# next query for page 536 for 17 games
# data retrieved
# next query for page 537 for 17 games
# data retrieved
# next query for page 538 for 17 games
# data retrieved
# next query for page 539 for 17 games
# data retrieved
# next query for page 540 for 17 games
# data retrieved
# next query for page 541 for 16 games
# data retrieved
# next query for page 542 for 16 games
# data retrieved
# next query for page 543 for 16 games
# data retrieved
# next query for page 544 for 16 games
# data retrieved
# next query for page 545 for 16 games
# data retrieved
# next query for page 546 for 15 games
# data retrieved
# next query for page 547 for 15 games
# data retrieved
# next query for page 548 for 15 games
# data retrieved
# next query for page 549 for 15 games
# data retrieved
# next query for page 550 for 14 games
# data retrieved
# next query for page 551 for 13 games
# data retrieved
# next query for page 552 for 13 games
# data retrieved
# next query for page 553 for 12 games
# data retrieved
# next query for page 554 for 11 games
# data retrieved
# next query for page 555 for 11 games
# data retrieved
# next query for page 556 for 11 games
# data retrieved
# next query for page 557 for 11 games
# data retrieved
# next query for page 558 for 11 games
# data retrieved
# next query for page 559 for 11 games
# data retrieved
# next query for page 560 for 11 games
# data retrieved
# next query for page 561 for 11 games
# data retrieved
# next query for page 562 for 11 games
# data retrieved
# next query for page 563 for 11 games
# data retrieved
# next query for page 564 for 11 games
# data retrieved
# next query for page 565 for 11 games
# data retrieved
# next query for page 566 for 11 games
# data retrieved
# next query for page 567 for 11 games
# data retrieved
# next query for page 568 for 11 games
# data retrieved
# next query for page 569 for 11 games
# data retrieved
# next query for page 570 for 11 games
# data retrieved
# next query for page 571 for 11 games
# data retrieved
# next query for page 572 for 11 games
# data retrieved
# next query for page 573 for 11 games
# data retrieved
# next query for page 574 for 11 games
# data retrieved
# next query for page 575 for 11 games
# data retrieved
# next query for page 576 for 11 games
# data retrieved
# next query for page 577 for 11 games
# data retrieved
# next query for page 578 for 11 games
# data retrieved
# next query for page 579 for 11 games
# data retrieved
# next query for page 580 for 11 games
# data retrieved
# next query for page 581 for 11 games
# data retrieved
# next query for page 582 for 10 games
# data retrieved
# next query for page 583 for 10 games
# data retrieved
# next query for page 584 for 10 games
# data retrieved
# next query for page 585 for 10 games
# data retrieved
# next query for page 586 for 10 games
# data retrieved
# next query for page 587 for 10 games
# data retrieved
# next query for page 588 for 10 games
# data retrieved
# next query for page 589 for 10 games
# data retrieved
# next query for page 590 for 10 games
# data retrieved
# next query for page 591 for 10 games
# data retrieved
# next query for page 592 for 10 games
# data retrieved
# next query for page 593 for 10 games
# data retrieved
# next query for page 594 for 10 games
# data retrieved
# next query for page 595 for 10 games
# data retrieved
# next query for page 596 for 10 games
# data retrieved
# next query for page 597 for 10 games
# data retrieved
# next query for page 598 for 9 games
# data retrieved
# next query for page 599 for 9 games
# data retrieved
# next query for page 600 for 9 games
# data retrieved
# next query for page 601 for 9 games
# data retrieved
# next query for page 602 for 9 games
# data retrieved
# next query for page 603 for 9 games
# data retrieved
# next query for page 604 for 9 games
# data retrieved
# next query for page 605 for 9 games
# data retrieved
# next query for page 606 for 9 games
# data retrieved
# next query for page 607 for 9 games
# data retrieved
# next query for page 608 for 9 games
# data retrieved
# next query for page 609 for 9 games
# data retrieved
# next query for page 610 for 9 games
# data retrieved
# next query for page 611 for 9 games
# data retrieved
# next query for page 612 for 9 games
# data retrieved
# next query for page 613 for 9 games
# data retrieved
# next query for page 614 for 9 games
# data retrieved
# next query for page 615 for 9 games
# data retrieved
# next query for page 616 for 9 games
# data retrieved
# next query for page 617 for 9 games
# data retrieved
# next query for page 618 for 8 games
# data retrieved
# next query for page 619 for 8 games
# data retrieved
# next query for page 620 for 8 games
# data retrieved
# next query for page 621 for 8 games
# data retrieved
# next query for page 622 for 7 games
# data retrieved
# next query for page 623 for 7 games
# data retrieved
# next query for page 624 for 7 games
# data retrieved
# next query for page 625 for 7 games
# data retrieved
# next query for page 626 for 7 games
# data retrieved
# next query for page 627 for 7 games
# data retrieved
# next query for page 628 for 7 games
# data retrieved
# next query for page 629 for 7 games
# data retrieved
# next query for page 630 for 7 games
# data retrieved
# next query for page 631 for 7 games
# data retrieved
# next query for page 632 for 7 games
# data retrieved
# next query for page 633 for 7 games
# data retrieved
# next query for page 634 for 6 games
# data retrieved
# next query for page 635 for 6 games
# data retrieved
# next query for page 636 for 6 games
# data retrieved
# next query for page 637 for 6 games
# data retrieved
# next query for page 638 for 6 games
# data retrieved
# next query for page 639 for 6 games
# data retrieved
# next query for page 640 for 6 games
# data retrieved
# next query for page 641 for 6 games
# data retrieved
# next query for page 642 for 6 games
# data retrieved
# next query for page 643 for 6 games
# data retrieved
# next query for page 644 for 6 games
# data retrieved
# next query for page 645 for 6 games
# data retrieved
# next query for page 646 for 6 games
# data retrieved
# next query for page 647 for 6 games
# data retrieved
# next query for page 648 for 6 games
# data retrieved
# next query for page 649 for 6 games
# data retrieved
# next query for page 650 for 6 games
# data retrieved
# next query for page 651 for 6 games
# data retrieved
# next query for page 652 for 6 games
# data retrieved
# next query for page 653 for 6 games
# data retrieved
# next query for page 654 for 6 games
# data retrieved
# next query for page 655 for 6 games
# data retrieved
# next query for page 656 for 6 games
# data retrieved
# next query for page 657 for 6 games
# data retrieved
# next query for page 658 for 6 games
# data retrieved
# next query for page 659 for 6 games
# data retrieved
# next query for page 660 for 6 games
# data retrieved
# next query for page 661 for 6 games
# data retrieved
# next query for page 662 for 6 games
# data retrieved
# next query for page 663 for 6 games
# data retrieved
# next query for page 664 for 6 games
# data retrieved
# next query for page 665 for 6 games
# data retrieved
# next query for page 666 for 6 games
# data retrieved
# next query for page 667 for 6 games
# data retrieved
# next query for page 668 for 6 games
# data retrieved
# next query for page 669 for 6 games
# data retrieved
# next query for page 670 for 6 games
# data retrieved
# next query for page 671 for 6 games
# data retrieved
# next query for page 672 for 6 games
# data retrieved
# next query for page 673 for 6 games
# data retrieved
# next query for page 674 for 6 games
# data retrieved
# next query for page 675 for 6 games
# data retrieved
# next query for page 676 for 6 games
# data retrieved
# next query for page 677 for 6 games
# data retrieved
# next query for page 678 for 6 games
# data retrieved
# next query for page 679 for 6 games
# data retrieved
# next query for page 680 for 6 games
# data retrieved
# next query for page 681 for 6 games
# data retrieved
# next query for page 682 for 6 games
# data retrieved
# next query for page 683 for 6 games
# data retrieved
# next query for page 684 for 6 games
# data retrieved
# next query for page 685 for 6 games
# data retrieved
# next query for page 686 for 5 games
# data retrieved
# next query for page 687 for 5 games
# data retrieved
# next query for page 688 for 5 games
# data retrieved
# next query for page 689 for 5 games
# data retrieved
# next query for page 690 for 5 games
# data retrieved
# next query for page 691 for 5 games
# data retrieved
# next query for page 692 for 5 games
# data retrieved
# next query for page 693 for 5 games
# data retrieved
# next query for page 694 for 5 games
# data retrieved
# next query for page 695 for 5 games
# data retrieved
# next query for page 696 for 5 games
# data retrieved
# next query for page 697 for 5 games
# data retrieved
# next query for page 698 for 5 games
# data retrieved
# next query for page 699 for 5 games
# data retrieved
# next query for page 700 for 5 games
# data retrieved
# next query for page 701 for 5 games
# data retrieved
# next query for page 702 for 5 games
# data retrieved
# next query for page 703 for 5 games
# data retrieved
# next query for page 704 for 5 games
# data retrieved
# next query for page 705 for 5 games
# data retrieved
# next query for page 706 for 5 games
# data retrieved
# next query for page 707 for 5 games
# data retrieved
# next query for page 708 for 5 games
# data retrieved
# next query for page 709 for 5 games
# data retrieved
# next query for page 710 for 5 games
# data retrieved
# next query for page 711 for 5 games
# data retrieved
# next query for page 712 for 5 games
# data retrieved
# next query for page 713 for 5 games
# data retrieved
# next query for page 714 for 5 games
# data retrieved
# next query for page 715 for 5 games
# data retrieved
# next query for page 716 for 5 games
# data retrieved
# next query for page 717 for 5 games
# data retrieved
# next query for page 718 for 5 games
# data retrieved
# next query for page 719 for 5 games
# data retrieved
# next query for page 720 for 5 games
# data retrieved
# next query for page 721 for 5 games
# data retrieved
# next query for page 722 for 5 games
# data retrieved
# next query for page 723 for 5 games
# data retrieved
# next query for page 724 for 5 games
# data retrieved
# next query for page 725 for 5 games
# data retrieved
# next query for page 726 for 5 games
# data retrieved
# next query for page 727 for 5 games
# data retrieved
# next query for page 728 for 5 games
# data retrieved
# next query for page 729 for 5 games
# data retrieved
# next query for page 730 for 5 games
# data retrieved
# next query for page 731 for 5 games
# data retrieved
# next query for page 732 for 5 games
# data retrieved
# next query for page 733 for 5 games
# data retrieved
# next query for page 734 for 5 games
# data retrieved
# next query for page 735 for 5 games
# data retrieved
# next query for page 736 for 5 games
# data retrieved
# next query for page 737 for 5 games
# data retrieved
# next query for page 738 for 5 games
# data retrieved
# next query for page 739 for 5 games
# data retrieved
# next query for page 740 for 5 games
# data retrieved
# next query for page 741 for 5 games
# data retrieved
# next query for page 742 for 5 games
# data retrieved
# next query for page 743 for 5 games
# data retrieved
# next query for page 744 for 5 games
# data retrieved
# next query for page 745 for 5 games
# data retrieved
# next query for page 746 for 5 games
# data retrieved
# next query for page 747 for 5 games
# data retrieved
# next query for page 748 for 5 games
# data retrieved
# next query for page 749 for 5 games
# data retrieved
# next query for page 750 for 5 games
# data retrieved
# next query for page 751 for 5 games
# data retrieved
# next query for page 752 for 5 games
# data retrieved
# next query for page 753 for 5 games
# data retrieved
# next query for page 754 for 5 games
# data retrieved
# next query for page 755 for 5 games
# data retrieved
# next query for page 756 for 5 games
# data retrieved
# next query for page 757 for 4 games
# data retrieved
# next query for page 758 for 4 games
# data retrieved
# next query for page 759 for 4 games
# data retrieved
# next query for page 760 for 4 games
# data retrieved
# next query for page 761 for 4 games
# data retrieved
# next query for page 762 for 4 games
# data retrieved
# next query for page 763 for 4 games
# data retrieved
# next query for page 764 for 4 games
# data retrieved
# next query for page 765 for 4 games
# data retrieved
# next query for page 766 for 4 games
# data retrieved
# next query for page 767 for 4 games
# data retrieved
# next query for page 768 for 4 games
# data retrieved
# next query for page 769 for 4 games
# data retrieved
# next query for page 770 for 4 games
# data retrieved
# next query for page 771 for 4 games
# data retrieved
# next query for page 772 for 4 games
# data retrieved
# next query for page 773 for 4 games
# data retrieved
# next query for page 774 for 4 games
# data retrieved
# next query for page 775 for 4 games
# data retrieved
# next query for page 776 for 4 games
# data retrieved
# next query for page 777 for 4 games
# data retrieved
# next query for page 778 for 4 games
# data retrieved
# next query for page 779 for 4 games
# data retrieved
# next query for page 780 for 4 games
# data retrieved
# next query for page 781 for 4 games
# data retrieved
# next query for page 782 for 4 games
# data retrieved
# next query for page 783 for 4 games
# data retrieved
# next query for page 784 for 4 games
# data retrieved
# next query for page 785 for 4 games
# data retrieved
# next query for page 786 for 4 games
# data retrieved
# next query for page 787 for 4 games
# data retrieved
# next query for page 788 for 4 games
# data retrieved
# next query for page 789 for 4 games
# data retrieved
# next query for page 790 for 4 games
# data retrieved
# next query for page 791 for 4 games
# data retrieved
# next query for page 792 for 4 games
# data retrieved
# next query for page 793 for 4 games
# data retrieved
# next query for page 794 for 4 games
# data retrieved
# next query for page 795 for 4 games
# data retrieved
# next query for page 796 for 4 games
# data retrieved
# next query for page 797 for 4 games
# data retrieved
# next query for page 798 for 4 games
# data retrieved
# next query for page 799 for 4 games
# data retrieved
# next query for page 800 for 4 games
# data retrieved
# next query for page 801 for 4 games
# data retrieved
# next query for page 802 for 4 games
# data retrieved
# next query for page 803 for 4 games
# data retrieved
# next query for page 804 for 4 games
# data retrieved
# next query for page 805 for 3 games
# data retrieved
# next query for page 806 for 3 games
# data retrieved
# next query for page 807 for 3 games
# data retrieved
# next query for page 808 for 3 games
# data retrieved
# next query for page 809 for 3 games
# data retrieved
# next query for page 810 for 3 games
# data retrieved
# next query for page 811 for 3 games
# data retrieved
# next query for page 812 for 3 games
# data retrieved
# next query for page 813 for 3 games
# data retrieved
# next query for page 814 for 3 games
# data retrieved
# next query for page 815 for 3 games
# data retrieved
# next query for page 816 for 3 games
# data retrieved
# next query for page 817 for 3 games
# data retrieved
# next query for page 818 for 3 games
# data retrieved
# next query for page 819 for 3 games
# data retrieved
# next query for page 820 for 3 games
# data retrieved
# next query for page 821 for 3 games
# data retrieved
# next query for page 822 for 3 games
# data retrieved
# next query for page 823 for 3 games
# data retrieved
# next query for page 824 for 3 games
# data retrieved
# next query for page 825 for 3 games
# data retrieved
# next query for page 826 for 3 games
# data retrieved
# next query for page 827 for 3 games
# data retrieved
# next query for page 828 for 3 games
# data retrieved
# next query for page 829 for 3 games
# data retrieved
# next query for page 830 for 3 games
# data retrieved
# next query for page 831 for 3 games
# data retrieved
# next query for page 832 for 3 games
# data retrieved
# next query for page 833 for 3 games
# data retrieved
# next query for page 834 for 3 games
# data retrieved
# next query for page 835 for 3 games
# data retrieved
# next query for page 836 for 3 games
# data retrieved
# next query for page 837 for 3 games
# data retrieved
# next query for page 838 for 3 games
# data retrieved
# next query for page 839 for 3 games
# data retrieved
# next query for page 840 for 3 games
# data retrieved
# next query for page 841 for 3 games
# data retrieved
# next query for page 842 for 3 games
# data retrieved
# next query for page 843 for 3 games
# data retrieved
# next query for page 844 for 3 games
# data retrieved
# next query for page 845 for 3 games
# data retrieved
# next query for page 846 for 3 games
# data retrieved
# next query for page 847 for 3 games
# data retrieved
# next query for page 848 for 3 games
# data retrieved
# next query for page 849 for 3 games
# data retrieved
# next query for page 850 for 3 games
# data retrieved
# next query for page 851 for 3 games
# data retrieved
# next query for page 852 for 3 games
# data retrieved
# next query for page 853 for 3 games
# data retrieved
# next query for page 854 for 3 games
# data retrieved
# next query for page 855 for 3 games
# data retrieved
# next query for page 856 for 3 games
# data retrieved
# next query for page 857 for 3 games
# data retrieved
# next query for page 858 for 3 games
# data retrieved
# next query for page 859 for 3 games
# data retrieved
# next query for page 860 for 3 games
# data retrieved
# next query for page 861 for 3 games
# data retrieved
# next query for page 862 for 3 games
# data retrieved
# next query for page 863 for 3 games
# data retrieved
# next query for page 864 for 3 games
# data retrieved
# next query for page 865 for 3 games
# data retrieved
# next query for page 866 for 3 games
# data retrieved
# next query for page 867 for 3 games
# data retrieved
# next query for page 868 for 3 games
# data retrieved
# next query for page 869 for 3 games
# data retrieved
# next query for page 870 for 3 games
# data retrieved
# next query for page 871 for 3 games
# data retrieved
# next query for page 872 for 3 games
# data retrieved
# next query for page 873 for 3 games
# data retrieved
# next query for page 874 for 3 games
# data retrieved
# next query for page 875 for 3 games
# data retrieved
# next query for page 876 for 3 games
# data retrieved
# next query for page 877 for 3 games
# data retrieved
# next query for page 878 for 3 games
# data retrieved
# next query for page 879 for 3 games
# data retrieved
# next query for page 880 for 3 games
# data retrieved
# next query for page 881 for 3 games
# data retrieved
# next query for page 882 for 3 games
# data retrieved
# next query for page 883 for 3 games
# data retrieved
# next query for page 884 for 3 games
# data retrieved
# next query for page 885 for 3 games
# data retrieved
# next query for page 886 for 3 games
# data retrieved
# next query for page 887 for 3 games
# data retrieved
# next query for page 888 for 3 games
# data retrieved
# next query for page 889 for 3 games
# data retrieved
# next query for page 890 for 3 games
# data retrieved
# next query for page 891 for 3 games
# data retrieved
# next query for page 892 for 3 games
# data retrieved
# next query for page 893 for 3 games
# data retrieved
# next query for page 894 for 3 games
# data retrieved
# next query for page 895 for 3 games
# data retrieved
# next query for page 896 for 3 games
# data retrieved
# next query for page 897 for 3 games
# data retrieved
# next query for page 898 for 3 games
# data retrieved
# next query for page 899 for 3 games
# data retrieved
# next query for page 900 for 3 games
# data retrieved
# next query for page 901 for 3 games
# data retrieved
# next query for page 902 for 3 games
# data retrieved
# next query for page 903 for 3 games
# data retrieved
# ...
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# 'str' object has no attribute 'values' Traceback (most recent call last):
#   File "<ipython-input-11-2152159d95cc>", line 7, in process_result
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
#   File "<ipython-input-11-2152159d95cc>", line 7, in <listcomp>
#     review_tup = [(g['@id'],) + tuple(review.values()) for review in g['comments']['comment']]
# AttributeError: 'str' object has no attribute 'values'
#
# new batch, slice(10700, 10800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(10800, 10900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(10900, 11000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11000, 11100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11100, 11200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11200, 11300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11300, 11400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11400, 11500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11500, 11600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11600, 11700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11700, 11800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11800, 11900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(11900, 12000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12000, 12100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12100, 12200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12200, 12300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12300, 12400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12400, 12500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12500, 12600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12600, 12700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12700, 12800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12800, 12900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(12900, 13000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13000, 13100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13100, 13200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13200, 13300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13300, 13400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13400, 13500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13500, 13600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13600, 13700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13700, 13800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13800, 13900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(13900, 14000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14000, 14100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14100, 14200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14200, 14300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14300, 14400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14400, 14500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14500, 14600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14600, 14700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14700, 14800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14800, 14900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(14900, 15000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15000, 15100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15100, 15200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15200, 15300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15300, 15400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15400, 15500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15500, 15600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15600, 15700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15700, 15800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15800, 15900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(15900, 16000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16000, 16100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16100, 16200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16200, 16300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16300, 16400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16400, 16500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16500, 16600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16600, 16700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16700, 16800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16800, 16900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(16900, 17000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17000, 17100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17100, 17200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17200, 17300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17300, 17400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17400, 17500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17500, 17600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17600, 17700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17700, 17800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17800, 17900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(17900, 18000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18000, 18100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18100, 18200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18200, 18300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18300, 18400, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18400, 18500, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18500, 18600, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18600, 18700, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18700, 18800, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18800, 18900, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(18900, 19000, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(19000, 19100, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(19100, 19200, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(19200, 19300, None)
# next query for page 0 for 100 games
# data retrieved
# next query for page 1 for 100 games
# data retrieved
# new batch, slice(19300, 19331, None)
# next query for page 0 for 30 games
# data retrieved
# next query for page 1 for 30 games
# data retrieved
# all done

# %%
# get tables from db
con = sqlite3.connect('test.db')
cursor = con.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('games',), ('reviews',)]

# %%
for val in ['user','rating','ID']:
    print(val,cur.execute("SELECT COUNT(*) FROM (SELECT DISTINCT "+ val +" FROM reviews);").fetchall())
# Out:
# user [(19330,)]
# rating [(351049,)]
# ID [(2743476,)]

# %% [markdown]
# # Import DB

# %%
import pandas as pd
import sqlite3

# Create your connection.
cnx = sqlite3.connect('test.db')
from aoc import timeit
with timeit(): df = pd.read_sql_query("SELECT * FROM reviews", cnx)
# Out:
# INFO:root:None, time: 7.077454209327698

# %%
df.to_csv('17mreviews.csv')

# %%
# Out:
# INFO:root:None, time: 1.8687207261721293

# %%
# Out:
# 351048

# %%
df.rename(columns={'user':'ID','rating':'user','comment':'rating','ID':'comment'},inplace=True)

# %%
df = df[['user', 'rating', 'comment','ID']]
df['ID'] = df['ID'].astype('int64')

# %%
df = df.merge(games[['ID','Name']],on='ID',how='left')

# %%
df.head()
# Out:
#               user  rating                                            comment  \
# 0          Torsten    10.0                                                NaN
# 1  mitnachtKAUBO-I    10.0  Hands down my favorite new game of BGG CON 200...
# 2           avlawn    10.0  I tend to either love or easily tire of co-op ...
# 3       Mike Mayer    10.0                                                NaN
# 4          Mease19    10.0  This is an amazing co-op game.  I play mostly ...
#
#       ID      Name
# 0  30549  Pandemic
# 1  30549  Pandemic
# 2  30549  Pandemic
# 3  30549  Pandemic
# 4  30549  Pandemic

# %%
len(df)
# Out:
# 17679583

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=True)

# %%
len(df)
# Out:
# 15864308

# %%
df.drop_duplicates(subset=['user','ID'], keep='first', inplace=True, ignore_index=True)

# %%
len(df)
# Out:
# 15823269

# %%
df['user'].nunique()
# Out:
# 1.002593585434211

# %%
filename = 'bgg-20m-reviews.csv'
df.rename(columns={'Name':'name'},inplace=True)
df.to_csv(filename)

# %%
import pandas as pd
import sqlite3
import aoc
filename = 'bgg-20m-reviews.csv'
with aoc.timeit(): df = pd.read_csv(filename,index_col=0)
